# %%
import spacy
from spacy.displacy import render
import pandas as pd
import numpy as np
import pymongo
from nltk.tokenize import sent_tokenize

# %%
nlp = spacy.load('en_core_web_md')

# %%
db = pymongo.MongoClient()['climate']
collection = db['evidences']
records = list(collection.find({}, {'_id': 0, 'evidence': 1}))
docs = [doc['evidence'].strip('.').strip('"').lower() for doc in records]
print(f"Corpus size: {len(docs)}")
print(f"Corpus sample: {docs[0]}")
# Out:
# Corpus size: 7675
# Corpus sample: recent research shows human activity driving earth towards global extinction event

# %%
tokens = []
for token in nlp(docs[1]):
    tokens.append({'text': token.text, 'lemma': token.lemma_, 'pos': token.pos_,
                   'tag': token.tag_, 'dep': token.dep_, 'shape': token.shape_,
                   'alpha': token.is_alpha, 'stopword': token.is_stop})
T = pd.DataFrame(tokens)

# %%
T
# Out:
#              text          lemma    pos   tag     dep shape  alpha  stopword
# 0   environmental  environmental    ADJ    JJ    amod  xxxx   True     False
# 1         impacts         impact   NOUN   NNS   nsubj  xxxx   True     False
# 2         include        include   VERB   VBP    ROOT  xxxx   True     False
# 3             the            the    DET    DT     det   xxx   True      True
# 4      extinction     extinction   NOUN    NN    dobj  xxxx   True     False
# 5              or             or  CCONJ    CC      cc    xx   True      True
# 6      relocation     relocation   NOUN    NN    conj  xxxx   True     False
# 7              of             of    ADP    IN    prep    xx   True      True
# 8            many           many    ADJ    JJ    amod  xxxx   True      True
# 9         species         specie   NOUN   NNS    pobj  xxxx   True     False
# 10             as             as  SCONJ    IN    mark    xx   True      True
# 11          their          their   PRON  PRP$    poss  xxxx   True      True
# 12     ecosystems      ecosystem   NOUN   NNS   nsubj  xxxx   True     False
# 13         change         change   VERB   VBP   advcl  xxxx   True     False
# 14              ,              ,  PUNCT     ,   punct     ,  False     False
# 15           most           most    ADV   RBS  advmod  xxxx   True      True
# 16    immediately    immediately    ADV    RB  advmod  xxxx   True     False
# 17            the            the    DET    DT     det   xxx   True      True
# 18   environments    environment   NOUN   NNS    conj  xxxx   True     False
# 19             of             of    ADP    IN    prep    xx   True      True
# 20          coral          coral    ADJ    JJ    amod  xxxx   True     False
# 21          reefs           reef   NOUN   NNS    pobj  xxxx   True     False
# 22              ,              ,  PUNCT     ,   punct     ,  False     False
# 23      mountains       mountain   NOUN   NNS    conj  xxxx   True     False
# 24              ,              ,  PUNCT     ,   punct     ,  False     False
# 25            and            and  CCONJ    CC      cc   xxx   True      True
# 26            the            the    DET    DT     det   xxx   True      True
# 27         arctic         arctic   NOUN    NN    conj  xxxx   True     False
